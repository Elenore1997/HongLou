# %%
import json
import codecs

with codecs.open('.json', 'r',encoding='utf-8') as json_str:
    json_dict = json.load(json_str)
    print(json_dict.keys())
    print(json_dict["categories"].keys())
    print(json_dict["data"].keys())
    print(json_dict["categories"])
    nodes = json_dict['data']['nodes']
    edges = json_dict['data']['edges']
# Out:
# dict_keys(['categories', 'data'])
# dict_keys(['person', 'event', 'location'])
# dict_keys(['nodes', 'edges'])
# {'person': '人物', 'event': '事件', 'location': '地点'}

# %%
person_nodes = []
for num, node in enumerate(nodes):
    if node['categories'][0] == 'person':
        person = node['label']
#         print(person)
        person_nodes.append(node)
print(len(person_nodes))
# Out:
# 贾宝玉
# 贾代善
# 贾代化
# 贾敷
# 贾敬
# 贾赦
# 贾政
# 贾蓉
# 贾蔷
# 贾兰
# 贾珍
# 贾琏
# 贾琮
# 贾珠
# 贾环
# 贾璜
# 贾演
# 贾源
# 秦钟
# 王子腾
# 王公之子
# 王仁
# 薛蟠
# 薛蝌
# 史鼐
# 史鼎
# 史侯之子
# 柳湘莲
# 贾雨村
# 贾瑞
# 蒋玉菡
# 贾芸
# 倪二
# 林如海
# 焦大
# 秦业
# 王公
# 贾代儒之子
# 薛公之孙
# 史侯
# 甄士隐
# 邢忠
# 板儿
# 孙绍祖
# 李贵
# 赵天梁
# 赵天栋
# 贾代儒
# 赖大
# 赵国基
# 吴贵
# 花自芳
# 王成之父
# 王成
# 狗儿
# 周瑞
# 林之孝
# 鲍二
# 金文翔
# 香怜
# 贾菌
# 贾蓝
# 金荣
# 茗烟
# 潘又安
# 贾芹
# 玉爱
# 来升
# 俞禄
# 杏奴
# 赖尚荣
# 金彩
# 邢德全
# 隆儿
# 兴儿
# 王善保
# 冷子兴
# 卜世仁
# 冯紫英
# 凤姐之父
# 史湘云之父
# 卫若兰
# 梅翰林之子
# 吴兴登
# 旺儿
# 封肃
# 李纨之哥
# 小沙弥
# 皇上
# 薛姨父
# 北静王
# 喜儿
# 寿儿
# 钱槐
# 乌进孝
# 南安郡王
# 冯渊
# 李守中
# 单聘仁
# 程日兴
# 詹光
# 昭儿
# 癞头和尚
# 跛足道人
# 霍启
# 旺儿之子
# 神瑛侍者
# 林黛玉
# 薛宝钗
# 贾巧姐
# 贾惜春
# 王熙凤
# 贾迎春
# 李纨
# 贾元春
# 贾探春
# 邢夫人
# 赵姨娘
# 贾敏
# 贾母
# 妙玉
# 王夫人
# 史湘云
# 秦可卿
# 晴雯
# 袭人
# 平儿
# 鸳鸯
# 紫鹃
# 莺儿
# 玉钏
# 金钏
# 彩云
# 司棋
# 芳官
# 麝月
# 香菱
# 抱琴
# 宝蟾
# 雪燕
# 春纤
# 文杏
# 碧月
# 琥珀
# 翠墨
# 薛姨妈
# 夏金桂
# 薛宝琴
# 邢岫烟
# 尤氏
# 尤二姐
# 尤三姐
# 刘姥姥
# 刘氏
# 同喜
# 小红
# 鲍二家的
# 瑞珠
# 藕官
# 蕊官
# 入画
# 彩屏
# 彩儿
# 丰儿
# 绣橘
# 侍书
# 小鹊
# 翠缕
# 榛儿
# 小螺
# 篆儿
# 茄官
# 善姐
# 素云
# 小吉祥儿
# 葵官
# 宝珠
# 同贵
# 炒豆儿
# 银蝶
# 小舍儿
# 艾官
# 文官
# 彩霞
# 娇红
# 秋桐
# 小吉祥
# 娇杏
# 菂官
# 旺儿媳妇
# 王嬷嬷
# 李嬷嬷
# 多姑娘
# 赖大家的
# 吴兴登家的
# 王善保家的
# 柳嫂子
# 李纹
# 李绮
# 李婶娘
# 青儿
# 周瑞家的
# 林之孝家的
# 柳五儿
# 秦显家的
# 莲花儿
# 金氏
# 五嫂子
# 来升媳妇
# 龄官
# 封氏
# 赖嬷嬷
# 周姨娘
# 翠云
# 嫣红
# 坠儿
# 智能儿
# 净虚
# 万儿
# 司棋母
# 白大娘
# 尤老娘
# 周奶奶
# 豆官
# 文花
# 赵嬷嬷
# 娄氏
# 老叶妈
# 周氏
# 佩凤
# 代儒夫人
# 春燕
# 何婆子
# 碧痕
# 笑儿
# 警幻仙姑
# 马道婆
# 南安太妃
# 夏婆子
# 费婆子
# 周瑞之女
# 绛珠仙子
# 242

# %%
import pandas as pd

person_df = pd.DataFrame(person_nodes)
person_df.head()
# Out:
#   categories    id                   image  \
# 0   [person]  3863  ./images/photo/贾宝玉.jpg
# 1   [person]  3864                     NaN
# 2   [person]  3865                     NaN
# 3   [person]  3866                     NaN
# 4   [person]  3867   ./images/photo/贾敬.jpg
#
#                                                 info label  value
# 0  荣国府衔玉而诞的公子，贾政与王夫人之次子，阖府捧为掌上明珠，对他寄予厚望，他却走上了叛逆之路...   贾宝玉     52
# 1  荣国公贾源是宁国公贾演的弟弟，贾源死后他的儿子贾代善袭了他的爵位。贾代善的夫人就是贾母（又称...   贾代善      8
# 2                        贾演长子，贾敷、贾敬之父，京营节度使世袭一等神威将军。   贾代化      5
# 3                                  贾代化长子，贾敬之兄。八九岁夭折。    贾敷      4
# 4  宁国公贾演的孙子，京营节度使世袭一等神威将军贾代化的次子，贾珍之父。是乙卯科进士，却一味好道...    贾敬      6

# %%
edges_df = pd.DataFrame(edges)
edges_df.head()
# Out:
#    from    id label    to
# 0  3838  3776    位于  3851
# 1  3839  3777    位于  3851
# 2  3840  3778    位于  3851
# 3  3841  3779    位于  3851
# 4  3842  3780    位于  3851

# %%
edges_rela = edges_df.label.value_counts()
edges_rela
# Out:
# 参与     187
# 仆人      80
# 居住地     61
# 父亲      54
# 原籍      42
# 母亲      39
# 丈夫      38
# 妻子      34
# 哥哥      26
# 交好      23
# 位于      15
# 同宗      13
# 姐姐      12
# 私通      12
# 姬妾      10
# 老师      10
# 喜欢       9
# 跟班       8
# 奶妈       5
# 干娘       5
# 知己       3
# 陪房       3
# 前世       2
# 连宗       2
# 有恩       1
# Name: label, dtype: int64

# %%
# 所有关系
relations = edges_df.label
relations = relations.tolist()
relations = list(set(relations))
print(relations)
print(len(relations))
print(type(relations[0]))
# Out:
# ['连宗', '交好', '同宗', '母亲', '奶妈', '前世', '知己', '姬妾', '丈夫', '参与', '位于', '干娘', '陪房', '哥哥', '姐姐', '有恩', '父亲', '跟班', '私通', '仆人', '原籍', '居住地', '喜欢', '妻子', '老师']
# 25
# <class 'str'>

# %%
rela_counts = []
for each in relations:
    rela_counts.append(int(edges_rela[each]))
print(rela_counts)
print(len(rela_counts))
print(type(rela_counts[0]))
# Out:
# [2, 23, 13, 39, 5, 2, 3, 10, 38, 187, 15, 5, 3, 26, 12, 1, 54, 8, 12, 80, 42, 61, 9, 34, 10]
# 25
# <class 'int'>

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

bar = Bar()
bar.add_xaxis(relations)
bar.add_yaxis('频次', rela_counts)
bar.set_global_opts(title_opts=opts.TitleOpts(title="红楼梦关系频次表"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d7d63b68463a4b0d9e040a4a5ad728dd" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d7d63b68463a4b0d9e040a4a5ad728dd = echarts.init(
#             document.getElementById('d7d63b68463a4b0d9e040a4a5ad728dd'), 'white', {renderer: 'canvas'});
#         var option_d7d63b68463a4b0d9e040a4a5ad728dd = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9891\u6b21",
#             "data": [
#                 2,
#                 23,
#                 13,
#                 39,
#                 5,
#                 2,
#                 3,
#                 10,
#                 38,
#                 187,
#                 15,
#                 5,
#                 3,
#                 26,
#                 12,
#                 1,
#                 54,
#                 8,
#                 12,
#                 80,
#                 42,
#                 61,
#                 9,
#                 34,
#                 10
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9891\u6b21"
#             ],
#             "selected": {
#                 "\u9891\u6b21": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8fde\u5b97",
#                 "\u4ea4\u597d",
#                 "\u540c\u5b97",
#                 "\u6bcd\u4eb2",
#                 "\u5976\u5988",
#                 "\u524d\u4e16",
#                 "\u77e5\u5df1",
#                 "\u59ec\u59be",
#                 "\u4e08\u592b",
#                 "\u53c2\u4e0e",
#                 "\u4f4d\u4e8e",
#                 "\u5e72\u5a18",
#                 "\u966a\u623f",
#                 "\u54e5\u54e5",
#                 "\u59d0\u59d0",
#                 "\u6709\u6069",
#                 "\u7236\u4eb2",
#                 "\u8ddf\u73ed",
#                 "\u79c1\u901a",
#                 "\u4ec6\u4eba",
#                 "\u539f\u7c4d",
#                 "\u5c45\u4f4f\u5730",
#                 "\u559c\u6b22",
#                 "\u59bb\u5b50",
#                 "\u8001\u5e08"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7ea2\u697c\u68a6\u5173\u7cfb\u9891\u6b21\u8868"
#         }
#     ]
# };
#         chart_d7d63b68463a4b0d9e040a4a5ad728dd.setOption(option_d7d63b68463a4b0d9e040a4a5ad728dd);
#     });
# </script>

# %% [markdown]
# #
